# %%
a = ['x','Y','abc',['N','O',['P']]]
a[3][2][0]
# Out:
# 'P'

# %%
yml = "My Name Is Khan"
yml[1:9]
# Out:
# 'y Name I'

# %%
# loop for list

li = ['2',3,5,7,'8',10,12,'16',18,19,21,26]
out = []
# print(type(li[0]))
for i in li:
    if type(i) == int:
        print(i)
        out.append(i)
out
# Out:
# 3
# 5
# 7
# 10
# 12
# 18
# 19
# 21
# 26
# [3, 5, 7, 10, 12, 18, 19, 21, 26]

# %%
Mystr = "MyNameisSatvikJha"
count = 0
for i in Mystr:
    if i == 'a':
        count = count + 1
        
print(str(count))
# Out:
# 3

# %%
Mystr = "MyNameisSatvikJha"
b = Mystr.count('a')
print(Mystr.replace('a','A'))
# Out:
# MyNAmeisSAtvikJhA

# %%
from collections import Counter
Mystr = "MyNameisSatvikJha"
count = Counter(Mystr)
print("i = "  + str(count['a']))
print(count['i'])
# Out:
# i = 3
# 2
