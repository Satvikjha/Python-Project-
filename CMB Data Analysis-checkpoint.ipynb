# %%
import pandas as pd
cmb = pd.read_csv("C:/Users/Satvik Jha/Desktop/27_08_01.csv",dtype = 'unicode',low_memory=False)
cmb.head(5)
ncmb = cmb.drop(["consult_tt","is_consult","phone_number","consult_to","is_transfer","is_conference","transfer_to","conference_to","email_id","user_register_phone"], axis ='columns')
#print(ncmb['centre'].count())
#print(len(pd.unique(ncmb['centre'])))
print("Total Center Is " + str(len(ncmb['centre'].unique())))
print(ncmb.nunique(axis = 0))
# Out:
# Total Center Is 13
# call_id_agent_id       159764
# call_id                157964
# call_type                   1
# attempt                     3
# campaign_name               7
# agent_id                 1338
# centre                     12
# disposition_code          344
# main_disposition           32
# sub_disposition           375
# system_disposition          7
# call_status                 1
# call_start_time         59088
# call_end_time           56250
# queue_duration            315
# ring_duration              71
# hold_duration             616
# talk_time                1333
# wrapup_time                37
# aht                      1480
# disconnection_party         3
# data_insert_time        48995
# data_dial_time          59088
# call_requested_time     49040
# language                    7
# sub_order_id           127872
# level1                 157856
# level2                      0
# user_code              123459
# free2                    1624
# ...
